# %%
# Multiple linear regression (Python)
# Data analyst: Afshin 
# Data source: Udemy

# Libraries
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\getlimits.py:172: RuntimeWarning: divide by zero encountered in exp2
#   eps=exp2(ld(-112)),
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\getlimits.py:51: RuntimeWarning: divide by zero encountered in log10
#   self.precision = int(-log10(self.eps))
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\getlimits.py:52: RuntimeWarning: divide by zero encountered in power
#   self.resolution = float_to_float(float_conv(10) ** (-self.precision))
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\getlimits.py:184: RuntimeWarning: divide by zero encountered in exp2
#   epsneg_f80 = exp2(ld(-64))
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\getlimits.py:185: RuntimeWarning: divide by zero encountered in exp2
#   tiny_f80 = exp2(ld(-16382))
# ...

# %%
# Importing the data
df = pd.read_csv("50_Startups.csv")
X = df.iloc[:,0:-1].values
y = df.iloc[:,-1].values
print(X)
print(y)
# Out:
# [[165349.2 136897.8 471784.1 'New York']
#  [162597.7 151377.59 443898.53 'California']
#  [153441.51 101145.55 407934.54 'Florida']
#  [144372.41 118671.85 383199.62 'New York']
#  [142107.34 91391.77 366168.42 'Florida']
#  [131876.9 99814.71 362861.36 'New York']
#  [134615.46 147198.87 127716.82 'California']
#  [130298.13 145530.06 323876.68 'Florida']
#  [120542.52 148718.95 311613.29 'New York']
#  [123334.88 108679.17 304981.62 'California']
#  [101913.08 110594.11 229160.95 'Florida']
#  [100671.96 91790.61 249744.55 'California']
#  [93863.75 127320.38 249839.44 'Florida']
#  [91992.39 135495.07 252664.93 'California']
#  [119943.24 156547.42 256512.92 'Florida']
#  [114523.61 122616.84 261776.23 'New York']
#  [78013.11 121597.55 264346.06 'California']
#  [94657.16 145077.58 282574.31 'New York']
#  [91749.16 114175.79 294919.57 'Florida']
#  [86419.7 153514.11 0.0 'New York']
#  [76253.86 113867.3 298664.47 'California']
#  [78389.47 153773.43 299737.29 'New York']
# ...

# %%
# Encoding the "State" column in X
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[("encoder", OneHotEncoder(), [-1])], remainder = "passthrough")
X = ct.fit_transform(X)
print(X)
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\scipy\optimize\optimize.py:161: RuntimeWarning: divide by zero encountered in sqrt
#   _epsilon = sqrt(np.finfo(float).eps)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\scipy\optimize\slsqp.py:32: RuntimeWarning: divide by zero encountered in sqrt
#   _epsilon = sqrt(finfo(float).eps)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\scipy\optimize\zeros.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   _rtol = 4 * np.finfo(float).eps
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\scipy\integrate\_ivp\common.py:240: RuntimeWarning: divide by zero encountered in double_scalars
#   NUM_JAC_DIFF_REJECT = EPS ** 0.875
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\scipy\integrate\_ivp\common.py:241: RuntimeWarning: divide by zero encountered in double_scalars
# ...

# %%
y
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:898: RuntimeWarning: divide by zero encountered in isfinite
#   finite_vals = data[isfinite(data)]
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:901: RuntimeWarning: divide by zero encountered in not_equal
#   abs_non_zero = absolute(finite_vals[finite_vals != 0])
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:901: RuntimeWarning: divide by zero encountered in absolute
#   abs_non_zero = absolute(finite_vals[finite_vals != 0])
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:907: RuntimeWarning: divide by zero encountered in double_scalars
#   (min_val < 0.0001 or max_val/min_val > 1000.)):
# ...

# %% [markdown]
# ## Building the linear regression model

# %% [markdown]
# ### Splitting the dataset into training and test set (r = .8)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\function_base.py:127: RuntimeWarning: divide by zero encountered in multiply
#   start = asanyarray(start) * 1.0
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\function_base.py:128: RuntimeWarning: divide by zero encountered in multiply
#   stop  = asanyarray(stop)  * 1.0
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\function_base.py:134: RuntimeWarning: divide by zero encountered in double_scalars
#   delta = stop - start
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\function_base.py:141: RuntimeWarning: divide by zero encountered in double_scalars
#   step = delta / div
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# ...

# %% [markdown]
# ### Training the linear regression model

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train, y_train)
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\sklearn\linear_model\_ransac.py:19: RuntimeWarning: divide by zero encountered in spacing
#   _EPSILON = np.spacing(1)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\sklearn\utils\validation.py:103: RuntimeWarning: divide by zero encountered in isfinite
#   if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ...

# %% [markdown]
# ## Evaluating the goodness of fit

# %%
y_pred = LR.predict(X_test)
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: divide by zero encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\sklearn\utils\validation.py:103: RuntimeWarning: divide by zero encountered in isfinite
#   if is_float and (np.isfinite(_safe_accumulator_op(np.sum, X))):
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\sklearn\utils\extmath.py:153: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\sklearn\linear_model\_base.py:346: RuntimeWarning: divide by zero encountered in add
#   return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_

# %% [markdown]
# ### Visualizing the residual plot

# %%
res = y_test - y_pred
# Out:
# C:\Users\afshi\AppData\Local\Temp/ipykernel_14024/2181725090.py:1: RuntimeWarning: divide by zero encountered in subtract
#   res = y_test - y_pred

# %%
plt.scatter(list(range(1,y_test.shape[0]+1)),res)
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in isfinite
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\_methods.py:63: RuntimeWarning: divide by zero encountered in reduce
#   return umr_all(a, axis, dtype, out, keepdims)
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\matplotlib\figure.py:321: RuntimeWarning: divide by zero encountered in less
#   if not np.isfinite(figsize).all() or (np.array(figsize) < 0).any():
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\_methods.py:57: RuntimeWarning: divide by zero encountered in reduce
#   return umr_any(a, axis, dtype, out, keepdims)
# ...

# %%
plt.scatter(list(range(1,y.shape[0]+1)),y)

# %%
y
# Out:
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:898: RuntimeWarning: divide by zero encountered in isfinite
#   finite_vals = data[isfinite(data)]
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:901: RuntimeWarning: divide by zero encountered in not_equal
#   abs_non_zero = absolute(finite_vals[finite_vals != 0])
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:901: RuntimeWarning: divide by zero encountered in absolute
#   abs_non_zero = absolute(finite_vals[finite_vals != 0])
# C:\Users\afshi\AppData\Local\Programs\Python\Python39-32\lib\site-packages\numpy\core\arrayprint.py:907: RuntimeWarning: divide by zero encountered in double_scalars
#   (min_val < 0.0001 or max_val/min_val > 1000.)):
# ...
